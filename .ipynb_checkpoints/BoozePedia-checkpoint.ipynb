# %%
import json
import urllib
import csv
urls = []

# for x in range(15111, 15113):
#     url = "http://www.thecocktaildb.com/api/json/v1/1/lookup.php?i=" + str(x)
#     urls.append(url)
    

# for url in urls:
#     urlopened = urllib.urlopen(url)
#     result = json.load(urlopened)  # result is now a dict
#     #print result['drinks'][0]['strDrink']
#     if not result['drinks'] == None:
#         print result['drinks'][0]['strDrink']
        
      
#print result['drinks'][0]['strDrink']
        
# x = json.loads(x)

f = csv.writer(open("test.csv", "wb+"), delimiter ='|',quotechar ='"',quoting=csv.QUOTE_MINIMAL)

# Write CSV Header, If you dont need that, remove this line
f.writerow(["idDrink", "strDrink", "strCategory", "strAlcoholic", "strGlass", "strInstructions", "strDrinkThumb", "strIngredient1", "strIngredient2", "strIngredient3", "strIngredient4", "strIngredient5", "strIngredient6", "strIngredient7", "strIngredient8", "strIngredient9", "strIngredient10", "strIngredient11", "strIngredient12", "strIngredient13", "strIngredient14", "strIngredient15"])

for x in range(10999, 14000):
    url = "http://www.thecocktaildb.com/api/json/v1/1/lookup.php?i=" + str(x)
    urls.append(url)
    

for url in urls:
    urlopened = urllib.urlopen(url)
    result = json.load(urlopened)  # result is now a dict
    #print result['drinks'][0]['strDrink']
    if not result['drinks'] == None:  
        localList = [result['drinks'][0]['idDrink'],
                   result['drinks'][0]['strDrink'],
                   result['drinks'][0]['strCategory'],
                   result['drinks'][0]['strAlcoholic'],
                   result['drinks'][0]['strInstructions'],
                   result['drinks'][0]['strDrinkThumb'],
                   result['drinks'][0]['strIngredient1'],
                   result['drinks'][0]['strIngredient2'],
                   result['drinks'][0]['strIngredient3'],
                   result['drinks'][0]['strIngredient4'],
                   result['drinks'][0]['strIngredient5'],
                   result['drinks'][0]['strIngredient6'],
                   result['drinks'][0]['strIngredient7'],
                   result['drinks'][0]['strIngredient9'],
                   result['drinks'][0]['strIngredient10'],
                   result['drinks'][0]['strIngredient11'],
                   result['drinks'][0]['strIngredient12'],
                   result['drinks'][0]['strIngredient13'],
                   result['drinks'][0]['strIngredient14'],
                   result['drinks'][0]['strIngredient15']]
        
        print "Hello"
        
        f.writerow([x.encode("utf-8") if x is not None else x for x in localList])
        

# for x in x:
#     f.writerow([x["pk"],
#                 x["model"],
#                 x["fields"]["codename"],
#                 x["fields"]["name"],
#                 x["fields"]["content_type"]])
# Out:
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# ...
